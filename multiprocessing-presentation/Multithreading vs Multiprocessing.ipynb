# %% [markdown]
# # Multithreading vs Multiprocessing
# - Both are the way to achieve MULTITASKING

# %% [markdown]
# ![Screenshot%20from%202018-10-11%2003-29-12.png](attachment:Screenshot%20from%202018-10-11%2003-29-12.png)

# %% [markdown]
# ![Screenshot%20from%202018-10-11%2003-29-23.png](attachment:Screenshot%20from%202018-10-11%2003-29-23.png)

# %% [markdown]
# # Key difference
# - executing multiple processes at the same time on multiple processors
# - executing concurrently using a single CPU only.
